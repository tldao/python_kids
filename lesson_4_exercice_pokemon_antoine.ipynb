# %%
from IPython.display import display
from IPython.display import Image
from IPython.lib.display import YouTubeVideo
from IPython.display import HTML
from colorama import Fore, Back, Style
# %pylab inline
src_path = "/Users/Ha Minh Huong/Documents/Works/Gaucon/Images/"
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
class MonPokemon():
    def __init__(self):
        self.combat =180 
        self.force = 270
        self.resitance = 120
        self.nom = "groudon"
        
    def dire_mon_nom(self):
        print Fore.RED + Back.YELLOW + "Mon nom est " + self.nom
        
    def me_montrer(self):
        filename = src_path + "groudon.png"
        test = Image(filename=filename, width=200)
        display(test)
        
    def attaquer(self):
        filename = src_path + "groudon attaque.jpg"
        test = Image(filename=filename, width=400)
        display(test)
    
    def chanter(self):
        test = YouTubeVideo('WaNpAHA9KeE', width=400)
        display(test)
    
    def pokepedia(self):
        ulr = 'https://www.pokepedia.fr/Pikachu'
        test = HTML(ulr)
        display(test)

    def evoluer(self):
        filename = src_path + "groudon.png"
        test = Image(filename=filename, width=200)
        display(test)
        
    def combattre(self):
        filename = src_path + "groudon vs kyogre.jpg"
        test = Image(filename=filename, width=400)
        display(test)

# %%
groudon = MonPokemon()

# %%
groudon.dire_mon_nom()
# Out:
# Mon nom est groudon

# %%
groudon.me_montrer()

# %%
groudon.attaquer()

# %%
groudon.force
# Out:
# 270

# %%
groudon.resitance
# Out:
# 120

# %%
groudon.combat
# Out:
# 180

# %%
groudon.chanter()

# %%
#pikachou.pokepedia()

# %%
groudon.evoluer()

# %%
groudon.combattre()
